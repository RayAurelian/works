# %%
import pandas as pd ; import matplotlib.pyplot as plt ; import numpy as npy ; from io import BytesIO
import requests 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import RobustScaler
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
import seaborn as sns

# %%
df=pd.read_csv('Laptop_price.csv')
price=df[['Price']]
df
model= df.drop('Price', axis = 1)

# %%
X_train, X_test,Y_train, Y_test = train_test_split(model,price, test_size=0.50, random_state=npy.random.randint(1000000))

# %%
num_colomns=list(X_train.select_dtypes(exclude=['object']).columns)
cat_columns=list(X_train.select_dtypes(include=['object']).columns)
numerical = Pipeline(steps=[
    ("simple_imputer", SimpleImputer(strategy='mean')),
    ("power_transform", PowerTransformer()),
    ("Scaler", StandardScaler())
])
categorical = Pipeline(steps=[
    ("simple_imputer", SimpleImputer(strategy='most_frequent')),
    ('OneHotEncoder', OneHotEncoder(handle_unknown='ignore',
                                    sparse_output=False))
])
ct=ColumnTransformer([
    ('numerical',numerical,num_colomns),
    ("categorical", categorical, cat_columns)
])
pipe=Pipeline(steps=[
    ("ct",ct),
    ("XGBRegressor", XGBRegressor())
])
param_grid={
    'XGBRegressor__n_estimators': [10, 11 , 20 ,  50], 
    'XGBRegressor__learning_rate': [0.1 , 0.111 , 0.333 , 0.666],
    'XGBRegressor__max_depth': [2, 5 , 6 , 15],
    'XGBRegressor__gamma': [0.1 , 0.111 , 0.333 , 0.666 ], 
    'XGBRegressor__booster': ['gbtree', 'gblinear'],
    'ct__numerical': [StandardScaler(), RobustScaler()],
}

# %%
clf = GridSearchCV(pipe,param_grid,verbose=3)

# %%
clf.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 1024 candidates, totalling 5120 fits
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.869 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.874 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.873 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.873 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.873 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.869 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.874 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.873 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.873 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.873 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.893 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.897 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.896 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.896 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.897 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.893 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.897 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.896 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.896 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.897 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.980 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.982 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.982 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.981 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.982 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.980 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.982 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.982 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.981 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.982 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.871 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.874 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.874 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.874 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.875 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.871 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.874 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.874 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.874 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.875 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.895 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.897 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.898 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.897 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.899 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.895 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.897 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.898 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.897 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.899 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.983 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.983 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.984 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.983 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.984 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.983 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.983 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.984 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.983 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.984 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=1.000 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.871 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.874 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.874 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.874 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.875 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.871 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.874 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.874 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.874 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.875 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.895 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.897 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.898 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.897 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.899 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.895 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.897 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.898 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.897 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.899 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.983 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.983 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.984 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.983 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.984 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.983 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.983 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.984 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.983 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.984 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=1.000 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=6, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.871 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.874 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.874 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.874 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.875 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.871 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.874 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.874 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.874 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.875 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.895 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.897 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.898 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.897 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.899 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.895 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.897 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.898 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.897 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.899 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.983 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.983 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.984 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.983 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.984 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.983 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.983 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.984 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.983 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.984 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.1s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.896 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.900 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.900 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.899 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.900 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.896 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.900 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.900 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.899 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.900 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.917 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.920 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.920 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.920 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.921 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.917 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.920 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.920 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.920 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.921 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.986 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.988 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.988 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.988 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.988 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.986 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.988 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.988 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.988 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.988 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=1.000 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=2, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.899 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.901 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.901 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.900 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=StandardScaler();, score=0.902 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.899 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.901 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.901 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.900 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=10, ct__numerical=RobustScaler();, score=0.902 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.919 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.921 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.922 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.921 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gbtree, XGBRegressor__gamma=0.1, XGBRegressor__learning_rate=0.111, XGBRegressor__max_depth=5, XGBRegressor__n_estimators=11, ct__numerical=StandardScaler();, score=0.922 total time=   0.0s
# ...
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV 2/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=11, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=1.000 total time=   0.0s
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV 3/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=1.000 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=StandardScaler();, score=1.000 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# [CV 4/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=20, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=1.000 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=1.000 total time=   0.0s
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV 4/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=StandardScaler();, score=1.000 total time=   0.0s
# [CV 1/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 2/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# [CV 3/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\work\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:28:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV 4/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=0.999 total time=   0.0s
# [CV 5/5] END XGBRegressor__booster=gblinear, XGBRegressor__gamma=0.666, XGBRegressor__learning_rate=0.666, XGBRegressor__max_depth=15, XGBRegressor__n_estimators=50, ct__numerical=RobustScaler();, score=1.000 total time=   0.0s
# GridSearchCV(estimator=Pipeline(steps=[('ct',
#                                         ColumnTransformer(transformers=[('numerical',
#                                                                          Pipeline(steps=[('simple_imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('power_transform',
#                                                                                           PowerTransformer()),
#                                                                                          ('Scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['Processor_Speed',
#                                                                           'RAM_Size',
#                                                                           'Storage_Capacity',
#                                                                           'Screen_Size',
#                                                                           'Weight']),
#                                                                         ('categorical',
#                                                                          Pipeline(steps=[('simple_imputer',
#                                                                                           SimpleImputer(str...
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      random_state=None, ...))]),
#              param_grid={'XGBRegressor__booster': ['gbtree', 'gblinear'],
#                          'XGBRegressor__gamma': [0.1, 0.111, 0.333, 0.666],
#                          'XGBRegressor__learning_rate': [0.1, 0.111, 0.333,
#                                                          0.666],
#                          'XGBRegressor__max_depth': [2, 5, 6, 15],
#                          'XGBRegressor__n_estimators': [10, 11, 20, 50],
#                          'ct__numerical': [StandardScaler(), RobustScaler()]},
#              verbose=3)

# %%
clf.score(X_test,Y_test)
# Out:
# 0.9995387103253452

# %%
modelstat=clf.best_estimator_
modelstat
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(transformers=[('numerical', RobustScaler(),
#                                                   ['Processor_Speed',
#                                                    'RAM_Size',
#                                                    'Storage_Capacity',
#                                                    'Screen_Size', 'Weight']),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('simple_imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('OneHotEncoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['Brand'])])),
#                 ('XGBRegres...
#                               feature_types=None, gamma=0.333, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.666,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=6, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=50, n_jobs=None,
#                               num_parallel_tree=None, random_state=None, ...))])

# %%
modelstat2=clf.best_params_  
modelstat2
# Out:
# {'XGBRegressor__booster': 'gblinear',
#  'XGBRegressor__gamma': 0.333,
#  'XGBRegressor__learning_rate': 0.666,
#  'XGBRegressor__max_depth': 6,
#  'XGBRegressor__n_estimators': 50,
#  'ct__numerical': RobustScaler()}
